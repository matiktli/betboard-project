# %%
# Static definitions
MATCH_DATE, MATCH_TIME = 'Date', 'Time'
MATCH_RESULT, MATCH_RESULT_HALFTIME = 'FTR', 'HTR'
HOME_TEAM, AWAY_TEAM = 'HomeTeam','AwayTeam'
HOME_TEAM_GOALS, AWAY_TEAM_GOALS = 'FTHG', 'FTAG'
HOME_TEAM_GOALS_HALFTIME, AWAY_TEAM_GOALS_HALFTIME = 'HTHG', 'HTAG'
HOME_TEAM_SHOTS, AWAY_TEAM_SHOTS = 'HS', 'AS'
HOME_TEAM_SHOTS_ON_TARGET, AWAY_TEAM_SHOTS_ON_TARGET = 'HST', 'AST'
HOME_TEAM_CORNERS, AWAY_TEAM_CORNERS = 'HC', 'AC'
HOME_TEAM_FOULS, AWAY_TEAM_FOULS = 'HF', 'AF'
HOME_TEAM_FREE_KICKS, AWAY_TEAM_FREE_KICKS = 'HFKC', 'AFKC'
HOME_TEAM_OFFSIDES, AWAY_TEAM_OFFSIDES = 'HO', 'AO'
HOME_TEAM_YELLOW, AWAY_TEAM_YELLOW = 'HY', 'AY'
HOME_TEAM_RED, AWAY_TEAM_RED = 'HR', 'AR'
BET365_HOME, BET365_AWAY, BET365_DRAW = 'B365H', 'B365A', 'B365D'

# %%
import pandas as pd

pl_18_19 = pd.read_csv('../resources/PremierLeague_18_19.csv')
pl_19_20 = pd.read_csv('../resources/PremierLeague_19_20.csv')
cl_18_19 = pd.read_csv('../resources/Championship_18_19.csv')
cl_19_20 = pd.read_csv('../resources/Championship_19_20.csv')

data = [pl_18_19,pl_19_20,cl_18_19,cl_19_20]
data = pd.concat(data)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

tmp = data.head(50)

is_home_win, is_away_win = tmp.FTR.eq('H'), tmp.FTR.eq('A')
print(is_home_win | is_away_win)
plt.plot(tmp[MATCH_DATE], tmp[HOME_TEAM_GOALS])
plt.plot(tmp[MATCH_DATE], tmp[AWAY_TEAM_GOALS])
plt.show()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23     True
# 24     True
# 25    False
# 26     True
# 27     True
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49    False
# Name: FTR, dtype: bool
